# %%
import pandas as pd

chemin_fichier_tsv = '../data/data_input/cv-corpus-18.0-delta-2024-06-14/fr/other.tsv'

df = pd.read_csv(chemin_fichier_tsv, sep='\t')

df.head()
# Out:
#                                            client_id  \
# 0  2079cb583f5baebeeb821abeda79e1a4977784c21f62dd...
# 1  2079cb583f5baebeeb821abeda79e1a4977784c21f62dd...
# 2  2079cb583f5baebeeb821abeda79e1a4977784c21f62dd...
# 3  2079cb583f5baebeeb821abeda79e1a4977784c21f62dd...
# 4  2079cb583f5baebeeb821abeda79e1a4977784c21f62dd...
#
#                            path  \
# 0  common_voice_fr_40187663.mp3
# 1  common_voice_fr_40187664.mp3
# 2  common_voice_fr_40187665.mp3
# 3  common_voice_fr_40187666.mp3
# 4  common_voice_fr_40187667.mp3
#
#                                          sentence_id  \
# 0  4f22a0239eeec1e761c9a59f9e9849adc74c3744f66c2a...
# 1  4f5e6b5126881fa9da952350b8215ae855730481543d35...
# 2  4f5a8da30220f09d709436baab194b67e6ccd1057a7592...
# 3  4f4e2f5a9a7baba926557505fe6e3927f84097a0b6e47f...
# 4  4f6245bd9304e4ec04d3f4c6f92f220757f25d964095e8...
#
#                                             sentence sentence_domain  \
# ...
